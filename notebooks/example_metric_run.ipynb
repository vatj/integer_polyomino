# %%
import sys, os
os.nice(15)
# Out:
# 15

# %%
import integer_polyomino.assembly as ipa
import integer_polyomino.gpmap as gp
sys.path.append(os.path.join(os.getcwd(), "..", "src", "integer_polyomino", "scripts"))
import graph_topo

# %%
data_dir = os.path.join(os.getcwd(), "..", "data", "V" + ipa.__version__)
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
p = dict()

p["n_genes"] = 4
p["low_colour"] = 0
p["high_colour"] = 6
p["threshold"] = 25
p["phenotype_builds"] = p["n_genes"] * 50
p["fixed_table"] = False
p["determinism"] = 1
p["genome_file"] = os.path.join(data_dir, "Genomes_N{n_genes}_C{high_colour}_T{threshold}_B{phenotype_builds}_D{determinism}_S{low_colour}.txt".format(**p))
p["table_file"] = os.path.join(data_dir, "PhenotypeTable_D{determinism}.txt".format(**p))
p["gpmap_file"] = os.path.join(data_dir, "Gpmap_N{n_genes}_C{high_colour}_T{threshold}_B{phenotype_builds}_D{determinism}_S{low_colour}.txt".format(**p))
p["threshold"] = p["threshold"] / 100

# %%
minimal_genomes = gp.MinimalGenomes(**p);
uniques = [];
for pIDs, genomes in gp.MinimalMap(**p).items():
    uniques.extend(graph_topo.TrimTopo(genomes))
    
print(len(uniques), len(minimal_genomes))
# Out:
# Generating all minimal samples
# Threshold is : 50.0 out of 200 builds
# Found 100 out of 245 generated
# Found 200 out of 834 generated
# Found 300 out of 2370 generated
# Found 400 out of 2619 generated
# Found 500 out of 3000 generated
# Found 600 out of 3501 generated
# Found 700 out of 4445 generated
# Found 800 out of 6051 generated
# Found 900 out of 6367 generated
# Found 1000 out of 6567 generated
# Found 1100 out of 6900 generated
# Found 1200 out of 7116 generated
# Found 1300 out of 7360 generated
# Found 1400 out of 8576 generated
# Found 1500 out of 8956 generated
# Found 1600 out of 9402 generated
# Found 1700 out of 9745 generated
# Found 1800 out of 10106 generated
# Found 1900 out of 11348 generated
# Found 2000 out of 11739 generated
# Found 2100 out of 12090 generated
# Found 2200 out of 12828 generated
# Found 2300 out of 13561 generated
# Found 2400 out of 15906 generated
# Found 2500 out of 16356 generated
# Found 2600 out of 19095 generated
# Found 2700 out of 22839 generated
# Found 2800 out of 34504 generated
# Found 2900 out of 37638 generated
# Found 3000 out of 39843 generated
# Found 3100 out of 40370 generated
# Found 3200 out of 40951 generated
# Found 3300 out of 41417 generated
# Found 3400 out of 41861 generated
# Found 3500 out of 44211 generated
# Found 3600 out of 44651 generated
# Found 3700 out of 45204 generated
# Found 3800 out of 46103 generated
# Found 3900 out of 47721 generated
# Found 4000 out of 48558 generated
# Found 4100 out of 49796 generated
# Found 4200 out of 50884 generated
# Found 4300 out of 54981 generated
# Found 4400 out of 56623 generated
# Found 4500 out of 66586 generated
# Found 4600 out of 67017 generated
# Found 4700 out of 67639 generated
# Found 4800 out of 69891 generated
# Found 4900 out of 70350 generated
# Found 5000 out of 70906 generated
# Found 5100 out of 71806 generated
# Found 5200 out of 73405 generated
# Found 5300 out of 74069 generated
# Found 5400 out of 75436 generated
# Found 5500 out of 76765 generated
# Found 5600 out of 80755 generated
# Found 5700 out of 81905 generated
# Found 5800 out of 83943 generated
# Found 5900 out of 86326 generated
# Found 6000 out of 94793 generated
# Found 6100 out of 107053 generated
# Found 6200 out of 108191 generated
# Found 6300 out of 111203 generated
# Found 6400 out of 112233 generated
# Found 6500 out of 114508 generated
# Found 6600 out of 119749 generated
# Found 6700 out of 222587 generated
# Found 6800 out of 223379 generated
# Found 6900 out of 225314 generated
# Found 7000 out of 225757 generated
# Found 7100 out of 226274 generated
# Found 7200 out of 226689 generated
# Found 7300 out of 228410 generated
# Found 7400 out of 229353 generated
# Found 7500 out of 229881 generated
# Found 7600 out of 231105 generated
# Found 7700 out of 232371 generated
# Found 7800 out of 236219 generated
# Found 7900 out of 237106 generated
# Found 8000 out of 250142 generated
# Found 8100 out of 251588 generated
# Found 8200 out of 252194 generated
# Found 8300 out of 253411 generated
# Found 8400 out of 254701 generated
# Found 8500 out of 255581 generated
# Found 8600 out of 256871 generated
# Found 8700 out of 258266 generated
# Found 8800 out of 262092 generated
# Found 8900 out of 263195 generated
# Found 9000 out of 263699 generated
# Found 9100 out of 265559 generated
# Found 9200 out of 266500 generated
# Found 9300 out of 267483 generated
# Found 9400 out of 269033 generated
# Found 9500 out of 273237 generated
# Found 9600 out of 274435 generated
# Found 9700 out of 285653 generated
# Found 9800 out of 301808 generated
# Found 9900 out of 308166 generated
# Found 10000 out of 328361 generated
# Found 10100 out of 337651 generated
# Found 10200 out of 345242 generated
# Found 10300 out of 406077 generated
# Found 10400 out of 406797 generated
# Found 10500 out of 407588 generated
# Found 10600 out of 408944 generated
# Found 10700 out of 410946 generated
# Found 10800 out of 414416 generated
# Found 10900 out of 424887 generated
# Found 11000 out of 436954 generated
# Found 11100 out of 461352 generated
# Found 11200 out of 478681 generated
# Found 11300 out of 518025 generated
# Found 11400 out of 557313 generated
# Found 11500 out of 581068 generated
# Found 11600 out of 709906 generated
# Found 11700 out of 710784 generated
# Found 11800 out of 768879 generated
# Found 11900 out of 1442541 generated
# Found 12000 out of 1446979 generated
# Found 12100 out of 1486237 generated
# Found 12200 out of 1531374 generated
# Found 12300 out of 1532967 generated
# Found 12400 out of 1554476 generated
# Found 12500 out of 1565911 generated
# Found 12600 out of 2358879 generated
# Found 12700 out of 2417025 generated
# Found 12800 out of 2474809 generated
# Found 12900 out of 2589173 generated
# Found 13000 out of 2604904 generated
# Found 13100 out of 2655817 generated
# Found 13200 out of 2718948 generated
# Found 13300 out of 2829537 generated
# Final Values : Found 13346 out of 5306251 generated
# Printing 13346 genomes to file : /u/rscratch/vatj2/Polyominoes/module/integer_polyomino/notebooks/../data/V0.1/Genomes_N4_C6_T25_B200_D1_S0.txt
# Loading genome from file : /u/rscratch/vatj2/Polyominoes/module/integer_polyomino/notebooks/../data/V0.1/Genomes_N4_C6_T25_B200_D1_S0.txt
# Mapping 13346 genomes, building 200 th times
# Currently preprocessing genome : 0 out of 13346
# Currently preprocessing genome : 100 out of 13346
# Currently preprocessing genome : 200 out of 13346
# Currently preprocessing genome : 300 out of 13346
# Currently preprocessing genome : 400 out of 13346
# Currently preprocessing genome : 500 out of 13346
# Currently preprocessing genome : 600 out of 13346
# Currently preprocessing genome : 700 out of 13346
# Currently preprocessing genome : 800 out of 13346
# Currently preprocessing genome : 900 out of 13346
# Currently preprocessing genome : 1000 out of 13346
# Currently preprocessing genome : 1100 out of 13346
# Currently preprocessing genome : 1200 out of 13346
# Currently preprocessing genome : 1300 out of 13346
# Currently preprocessing genome : 1400 out of 13346
# Currently preprocessing genome : 1500 out of 13346
# Currently preprocessing genome : 1600 out of 13346
# Currently preprocessing genome : 1700 out of 13346
# Currently preprocessing genome : 1800 out of 13346
# Currently preprocessing genome : 1900 out of 13346
# Currently preprocessing genome : 2000 out of 13346
# Currently preprocessing genome : 2100 out of 13346
# Currently preprocessing genome : 2200 out of 13346
# Currently preprocessing genome : 2300 out of 13346
# Currently preprocessing genome : 2400 out of 13346
# Currently preprocessing genome : 2500 out of 13346
# Currently preprocessing genome : 2600 out of 13346
# Currently preprocessing genome : 2700 out of 13346
# Currently preprocessing genome : 2800 out of 13346
# Currently preprocessing genome : 2900 out of 13346
# Currently preprocessing genome : 3000 out of 13346
# Currently preprocessing genome : 3100 out of 13346
# Currently preprocessing genome : 3200 out of 13346
# Currently preprocessing genome : 3300 out of 13346
# Currently preprocessing genome : 3400 out of 13346
# Currently preprocessing genome : 3500 out of 13346
# Currently preprocessing genome : 3600 out of 13346
# Currently preprocessing genome : 3700 out of 13346
# Currently preprocessing genome : 3800 out of 13346
# Currently preprocessing genome : 3900 out of 13346
# Currently preprocessing genome : 4000 out of 13346
# Currently preprocessing genome : 4100 out of 13346
# Currently preprocessing genome : 4200 out of 13346
# Currently preprocessing genome : 4300 out of 13346
# Currently preprocessing genome : 4400 out of 13346
# Currently preprocessing genome : 4500 out of 13346
# Currently preprocessing genome : 4600 out of 13346
# Currently preprocessing genome : 4700 out of 13346
# Currently preprocessing genome : 4800 out of 13346
# Currently preprocessing genome : 4900 out of 13346
# Currently preprocessing genome : 5000 out of 13346
# Currently preprocessing genome : 5100 out of 13346
# Currently preprocessing genome : 5200 out of 13346
# Currently preprocessing genome : 5300 out of 13346
# Currently preprocessing genome : 5400 out of 13346
# Currently preprocessing genome : 5500 out of 13346
# Currently preprocessing genome : 5600 out of 13346
# Currently preprocessing genome : 5700 out of 13346
# Currently preprocessing genome : 5800 out of 13346
# Currently preprocessing genome : 5900 out of 13346
# Currently preprocessing genome : 6000 out of 13346
# Currently preprocessing genome : 6100 out of 13346
# Currently preprocessing genome : 6200 out of 13346
# Currently preprocessing genome : 6300 out of 13346
# Currently preprocessing genome : 6400 out of 13346
# Currently preprocessing genome : 6500 out of 13346
# Currently preprocessing genome : 6600 out of 13346
# Currently preprocessing genome : 6700 out of 13346
# Currently preprocessing genome : 6800 out of 13346
# Currently preprocessing genome : 6900 out of 13346
# Currently preprocessing genome : 7000 out of 13346
# Currently preprocessing genome : 7100 out of 13346
# Currently preprocessing genome : 7200 out of 13346
# Currently preprocessing genome : 7300 out of 13346
# Currently preprocessing genome : 7400 out of 13346
# Currently preprocessing genome : 7500 out of 13346
# Currently preprocessing genome : 7600 out of 13346
# Currently preprocessing genome : 7700 out of 13346
# Currently preprocessing genome : 7800 out of 13346
# Currently preprocessing genome : 7900 out of 13346
# Currently preprocessing genome : 8000 out of 13346
# Currently preprocessing genome : 8100 out of 13346
# Currently preprocessing genome : 8200 out of 13346
# Currently preprocessing genome : 8300 out of 13346
# Currently preprocessing genome : 8400 out of 13346
# Currently preprocessing genome : 8500 out of 13346
# Currently preprocessing genome : 8600 out of 13346
# Currently preprocessing genome : 8700 out of 13346
# Currently preprocessing genome : 8800 out of 13346
# Currently preprocessing genome : 8900 out of 13346
# Currently preprocessing genome : 9000 out of 13346
# Currently preprocessing genome : 9100 out of 13346
# Currently preprocessing genome : 9200 out of 13346
# Currently preprocessing genome : 9300 out of 13346
# Currently preprocessing genome : 9400 out of 13346
# Currently preprocessing genome : 9500 out of 13346
# Currently preprocessing genome : 9600 out of 13346
# Currently preprocessing genome : 9700 out of 13346
# Currently preprocessing genome : 9800 out of 13346
# Currently preprocessing genome : 9900 out of 13346
# Currently preprocessing genome : 10000 out of 13346
# Currently preprocessing genome : 10100 out of 13346
# Currently preprocessing genome : 10200 out of 13346
# Currently preprocessing genome : 10300 out of 13346
# Currently preprocessing genome : 10400 out of 13346
# Currently preprocessing genome : 10500 out of 13346
# Currently preprocessing genome : 10600 out of 13346
# Currently preprocessing genome : 10700 out of 13346
# Currently preprocessing genome : 10800 out of 13346
# Currently preprocessing genome : 10900 out of 13346
# Currently preprocessing genome : 11000 out of 13346
# Currently preprocessing genome : 11100 out of 13346
# Currently preprocessing genome : 11200 out of 13346
# Currently preprocessing genome : 11300 out of 13346
# Currently preprocessing genome : 11400 out of 13346
# Currently preprocessing genome : 11500 out of 13346
# Currently preprocessing genome : 11600 out of 13346
# Currently preprocessing genome : 11700 out of 13346
# Currently preprocessing genome : 11800 out of 13346
# Currently preprocessing genome : 11900 out of 13346
# Currently preprocessing genome : 12000 out of 13346
# Currently preprocessing genome : 12100 out of 13346
# Currently preprocessing genome : 12200 out of 13346
# Currently preprocessing genome : 12300 out of 13346
# Currently preprocessing genome : 12400 out of 13346
# Currently preprocessing genome : 12500 out of 13346
# Currently preprocessing genome : 12600 out of 13346
# Currently preprocessing genome : 12700 out of 13346
# Currently preprocessing genome : 12800 out of 13346
# Currently preprocessing genome : 12900 out of 13346
# Currently preprocessing genome : 13000 out of 13346
# Currently preprocessing genome : 13100 out of 13346
# Currently preprocessing genome : 13200 out of 13346
# Currently preprocessing genome : 13300 out of 13346
# The GP-Map has been built!
# Printing preprocessed genomes to file : /u/rscratch/vatj2/Polyominoes/module/integer_polyomino/notebooks/../data/V0.1/Gpmap_N4_C6_T25_B200_D1_S0.txt
# 9941 13346

# %%
p["gen_colour"] = p["high_colour"]
p["high_colour"] += 2
p["n_jiggle"] = 1000
p["dup_aware"] = False
p.pop("genome_file", None)
p["genomes"] = uniques
p["genome_metric_file"] = os.path.join(data_dir, "GenomeMetrics_N{n_genes}_C{gen_colour}_T{threshold}_B{phenotype_builds}_Cx{high_colour}_J{n_jiggle}_D{determinism}_S{low_colour}.txt".format(**p))
p["set_metric_file"] = os.path.join(data_dir, "SetMetrics_N{n_genes}_C{gen_colour}_T{threshold}_B{phenotype_builds}_Cx{high_colour}_J{n_jiggle}_D{determinism}_S{low_colour}.txt".format(**p))

# %%
gp.MetricSampling(**p)
# Out:
# Mapping 9941 genomes, building 200 th times
# Currently preprocessing genome : 0 out of 9941
# Currently preprocessing genome : 100 out of 9941
# Currently preprocessing genome : 200 out of 9941
# Currently preprocessing genome : 300 out of 9941
# Currently preprocessing genome : 400 out of 9941
# Currently preprocessing genome : 500 out of 9941
# Currently preprocessing genome : 600 out of 9941
# Currently preprocessing genome : 700 out of 9941
# Currently preprocessing genome : 800 out of 9941
# Currently preprocessing genome : 900 out of 9941
# Currently preprocessing genome : 1000 out of 9941
# Currently preprocessing genome : 1100 out of 9941
# Currently preprocessing genome : 1200 out of 9941
# Currently preprocessing genome : 1300 out of 9941
# Currently preprocessing genome : 1400 out of 9941
# Currently preprocessing genome : 1500 out of 9941
# Currently preprocessing genome : 1600 out of 9941
# Currently preprocessing genome : 1700 out of 9941
# Currently preprocessing genome : 1800 out of 9941
# Currently preprocessing genome : 1900 out of 9941
# Currently preprocessing genome : 2000 out of 9941
# Currently preprocessing genome : 2100 out of 9941
# Currently preprocessing genome : 2200 out of 9941
# Currently preprocessing genome : 2300 out of 9941
# Currently preprocessing genome : 2400 out of 9941
# Currently preprocessing genome : 2500 out of 9941
# Currently preprocessing genome : 2600 out of 9941
# Currently preprocessing genome : 2700 out of 9941
# Currently preprocessing genome : 2800 out of 9941
# Currently preprocessing genome : 2900 out of 9941
# Currently preprocessing genome : 3000 out of 9941
# Currently preprocessing genome : 3100 out of 9941
# Currently preprocessing genome : 3200 out of 9941
# Currently preprocessing genome : 3300 out of 9941
# Currently preprocessing genome : 3400 out of 9941
# Currently preprocessing genome : 3500 out of 9941
# Currently preprocessing genome : 3600 out of 9941
# Currently preprocessing genome : 3700 out of 9941
# Currently preprocessing genome : 3800 out of 9941
# Currently preprocessing genome : 3900 out of 9941
# Currently preprocessing genome : 4000 out of 9941
# Currently preprocessing genome : 4100 out of 9941
# Currently preprocessing genome : 4200 out of 9941
# Currently preprocessing genome : 4300 out of 9941
# Currently preprocessing genome : 4400 out of 9941
# Currently preprocessing genome : 4500 out of 9941
# Currently preprocessing genome : 4600 out of 9941
# Currently preprocessing genome : 4700 out of 9941
# Currently preprocessing genome : 4800 out of 9941
# Currently preprocessing genome : 4900 out of 9941
# Currently preprocessing genome : 5000 out of 9941
# Currently preprocessing genome : 5100 out of 9941
# Currently preprocessing genome : 5200 out of 9941
# Currently preprocessing genome : 5300 out of 9941
# Currently preprocessing genome : 5400 out of 9941
# Currently preprocessing genome : 5500 out of 9941
# Currently preprocessing genome : 5600 out of 9941
# Currently preprocessing genome : 5700 out of 9941
# Currently preprocessing genome : 5800 out of 9941
# Currently preprocessing genome : 5900 out of 9941
# Currently preprocessing genome : 6000 out of 9941
# Currently preprocessing genome : 6100 out of 9941
# Currently preprocessing genome : 6200 out of 9941
# Currently preprocessing genome : 6300 out of 9941
# Currently preprocessing genome : 6400 out of 9941
# Currently preprocessing genome : 6500 out of 9941
# Currently preprocessing genome : 6600 out of 9941
# Currently preprocessing genome : 6700 out of 9941
# Currently preprocessing genome : 6800 out of 9941
# Currently preprocessing genome : 6900 out of 9941
# Currently preprocessing genome : 7000 out of 9941
# Currently preprocessing genome : 7100 out of 9941
# Currently preprocessing genome : 7200 out of 9941
# Currently preprocessing genome : 7300 out of 9941
# Currently preprocessing genome : 7400 out of 9941
# Currently preprocessing genome : 7500 out of 9941
# Currently preprocessing genome : 7600 out of 9941
# Currently preprocessing genome : 7700 out of 9941
# Currently preprocessing genome : 7800 out of 9941
# Currently preprocessing genome : 7900 out of 9941
# Currently preprocessing genome : 8000 out of 9941
# Currently preprocessing genome : 8100 out of 9941
# Currently preprocessing genome : 8200 out of 9941
# Currently preprocessing genome : 8300 out of 9941
# Currently preprocessing genome : 8400 out of 9941
# Currently preprocessing genome : 8500 out of 9941
# Currently preprocessing genome : 8600 out of 9941
# Currently preprocessing genome : 8700 out of 9941
# Currently preprocessing genome : 8800 out of 9941
# Currently preprocessing genome : 8900 out of 9941
# Currently preprocessing genome : 9000 out of 9941
# Currently preprocessing genome : 9100 out of 9941
# Currently preprocessing genome : 9200 out of 9941
# Currently preprocessing genome : 9300 out of 9941
# Currently preprocessing genome : 9400 out of 9941
# Currently preprocessing genome : 9500 out of 9941
# Currently preprocessing genome : 9600 out of 9941
# Currently preprocessing genome : 9700 out of 9941
# Currently preprocessing genome : 9800 out of 9941
# Currently preprocessing genome : 9900 out of 9941
# The GP-Map has been built!
# There are 9941 genomes to jiggle a 1000 times!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 2 , 0 ), }. Only  9940  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 2 , 0 ), ( 3 , 0 ), }. Only  9938  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 2 , 0 ), ( 3 , 1 ), }. Only  9937  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 2 , 0 ), ( 4 , 1 ), }. Only  9936  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 2 , 0 ), ( 7 , 2 ), }. Only  9934  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 2 , 0 ), ( 10 , 0 ), }. Only  9932  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 2 , 0 ), ( 12 , 0 ), }. Only  9931  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 0 ), }. Only  9930  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 0 ), ( 4 , 1 ), }. Only  9929  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 0 ), ( 5 , 1 ), }. Only  9928  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 3 , 0 ), ( 7 , 2 ), }. Only  9926  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 0 ), ( 10 , 0 ), }. Only  9925  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 0 ), ( 12 , 0 ), }. Only  9924  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 3 , 1 ), }. Only  9922  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 1 ), ( 7 , 2 ), }. Only  9921  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 3 , 1 ), ( 10 , 0 ), }. Only  9919  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 3 , 1 ), ( 12 , 0 ), }. Only  9918  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), }. Only  9917  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 8 , 6 ), }. Only  9915  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 8 , 7 ), }. Only  9914  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 9 , 0 ), }. Only  9913  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 9 , 2 ), }. Only  9912  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 9 , 3 ), }. Only  9911  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 10 , 6 ), }. Only  9909  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 10 , 12 ), }. Only  9908  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 0 ), ( 12 , 0 ), }. Only  9907  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 4 , 1 ), }. Only  9904  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 4 , 1 ), ( 5 , 1 ), }. Only  9902  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 4 , 1 ), ( 7 , 2 ), }. Only  9900  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 2 ), }. Only  9899  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 4 , 2 ), ( 8 , 0 ), }. Only  9897  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 3 ), }. Only  9896  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 4 , 4 ), }. Only  9895  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 5 , 0 ), }. Only  9892  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 0 ), ( 6 , 0 ), }. Only  9891  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 0 ), ( 7 , 3 ), }. Only  9890  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 0 ), ( 7 , 3 ), ( 9 , 3 ), }. Only  9889  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 5 , 1 ), }. Only  9887  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 1 ), ( 6 , 0 ), }. Only  9886  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 5 , 1 ), ( 7 , 2 ), }. Only  9884  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 1 ), ( 12 , 0 ), }. Only  9883  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 2 ), }. Only  9882  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 5 , 3 ), }. Only  9881  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 0 ), ( 7 , 4 ), }. Only  9880  left!
# Currently processing 28 genomes for { ( 0 , 0 ), ( 6 , 1 ), }. Only  9852  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 7 , 3 ), }. Only  9851  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 8 , 6 ), }. Only  9849  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 8 , 8 ), }. Only  9848  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 9 , 3 ), }. Only  9847  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 10 , 9 ), }. Only  9845  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 10 , 11 ), }. Only  9844  left!
# Currently processing 6 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 16 , 0 ), }. Only  9838  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 17 , 2 ), }. Only  9837  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 1 ), ( 20 , 0 ), }. Only  9836  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 6 , 6 ), }. Only  9834  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 6 ), ( 6 , 8 ), }. Only  9833  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 6 , 6 ), ( 8 , 9 ), }. Only  9832  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 6 , 11 ), }. Only  9830  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 0 ), ( 8 , 11 ), }. Only  9829  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 0 ), ( 8 , 26 ), }. Only  9828  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 7 , 2 ), }. Only  9825  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 2 ), ( 8 , 0 ), }. Only  9824  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 7 , 2 ), ( 8 , 9 ), }. Only  9822  left!
# Currently processing 22 genomes for { ( 0 , 0 ), ( 7 , 3 ), }. Only  9800  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 8 , 6 ), }. Only  9799  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 8 , 8 ), ( 10 , 12 ), }. Only  9798  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 9 , 3 ), }. Only  9796  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 10 , 6 ), }. Only  9794  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 10 , 10 ), }. Only  9793  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 10 , 12 ), }. Only  9792  left!
# Currently processing 4 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 16 , 0 ), }. Only  9788  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 3 ), ( 17 , 2 ), }. Only  9787  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 7 , 4 ), }. Only  9784  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 7 , 5 ), }. Only  9781  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 6 ), ( 9 , 4 ), }. Only  9780  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 8 ), }. Only  9779  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 9 ), }. Only  9778  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 9 ), ( 9 , 5 ), }. Only  9777  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 9 ), ( 9 , 6 ), }. Only  9776  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 7 , 10 ), ( 8 , 16 ), }. Only  9775  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 0 ), }. Only  9773  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 0 ), ( 8 , 11 ), }. Only  9772  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 0 ), ( 10 , 0 ), }. Only  9770  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 0 ), ( 10 , 15 ), }. Only  9768  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 0 ), ( 20 , 20 ), ( 24 , 2 ), }. Only  9767  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 2 ), }. Only  9766  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 2 ), ( 9 , 9 ), }. Only  9765  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 3 ), }. Only  9764  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 4 ), }. Only  9763  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 8 , 5 ), }. Only  9760  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 5 ), ( 20 , 9 ), ( 24 , 1 ), }. Only  9759  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 8 , 6 ), }. Only  9756  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 6 ), ( 8 , 7 ), }. Only  9755  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 6 ), ( 8 , 11 ), }. Only  9754  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 8 , 6 ), ( 10 , 9 ), }. Only  9751  left!
# Currently processing 6 genomes for { ( 0 , 0 ), ( 8 , 7 ), }. Only  9745  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 7 ), ( 9 , 0 ), }. Only  9744  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 7 ), ( 10 , 6 ), }. Only  9743  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 7 ), ( 12 , 0 ), }. Only  9742  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 8 ), }. Only  9740  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 8 ), ( 9 , 3 ), }. Only  9739  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 8 ), ( 10 , 12 ), }. Only  9737  left!
# Currently processing 4 genomes for { ( 0 , 0 ), ( 8 , 8 ), ( 12 , 3 ), }. Only  9733  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 8 ), ( 20 , 0 ), }. Only  9732  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 10 ), ( 8 , 11 ), }. Only  9731  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 11 ), }. Only  9729  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 12 ), ( 10 , 0 ), }. Only  9727  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 17 ), }. Only  9726  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 18 ), }. Only  9725  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 8 , 20 ), }. Only  9723  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 8 , 26 ), ( 9 , 18 ), }. Only  9722  left!
# Currently processing 11 genomes for { ( 0 , 0 ), ( 9 , 0 ), }. Only  9711  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 0 ), ( 9 , 12 ), }. Only  9710  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 0 ), ( 10 , 2 ), }. Only  9709  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 0 ), ( 11 , 16 ), }. Only  9708  left!
# Currently processing 5 genomes for { ( 0 , 0 ), ( 9 , 0 ), ( 12 , 6 ), }. Only  9703  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 0 ), ( 14 , 5 ), }. Only  9702  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 0 ), ( 15 , 8 ), }. Only  9701  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 9 , 1 ), }. Only  9699  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 9 , 2 ), }. Only  9697  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 9 , 3 ), }. Only  9695  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 3 ), ( 10 , 9 ), ( 12 , 3 ), }. Only  9694  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 9 , 5 ), }. Only  9692  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 9 , 6 ), }. Only  9690  left!
# Currently processing 4 genomes for { ( 0 , 0 ), ( 9 , 7 ), }. Only  9686  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 7 ), ( 10 , 3 ), }. Only  9685  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 10 ), }. Only  9684  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 11 ), ( 12 , 0 ), }. Only  9683  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 9 , 12 ), ( 10 , 16 ), }. Only  9680  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 9 , 12 ), ( 10 , 17 ), }. Only  9679  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 9 , 14 ), }. Only  9676  left!
# Currently processing 7 genomes for { ( 0 , 0 ), ( 10 , 0 ), }. Only  9669  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 0 ), ( 12 , 0 ), }. Only  9668  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 10 , 1 ), }. Only  9666  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 2 ), ( 13 , 0 ), }. Only  9665  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 3 ), ( 11 , 1 ), }. Only  9664  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 3 ), ( 13 , 1 ), }. Only  9663  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 10 , 4 ), }. Only  9661  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 4 ), ( 10 , 52 ), }. Only  9660  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 4 ), ( 12 , 20 ), }. Only  9659  left!
# Currently processing 4 genomes for { ( 0 , 0 ), ( 10 , 6 ), }. Only  9655  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 10 , 6 ), ( 12 , 0 ), }. Only  9653  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 9 ), }. Only  9652  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 9 ), ( 12 , 3 ), }. Only  9651  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 9 ), ( 12 , 3 ), ( 20 , 0 ), }. Only  9650  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 10 ), }. Only  9649  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 10 ), ( 11 , 3 ), }. Only  9648  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 13 ), ( 11 , 14 ), }. Only  9647  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 74 ), }. Only  9646  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 10 , 86 ), ( 11 , 27 ), }. Only  9645  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 0 ), }. Only  9644  left!
# Currently processing 4 genomes for { ( 0 , 0 ), ( 11 , 1 ), }. Only  9640  left!
# Currently processing 5 genomes for { ( 0 , 0 ), ( 11 , 4 ), }. Only  9635  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 11 , 5 ), }. Only  9633  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 5 ), ( 13 , 30 ), }. Only  9632  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 11 , 6 ), ( 12 , 4 ), }. Only  9630  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 11 , 8 ), ( 12 , 5 ), }. Only  9628  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 9 ), }. Only  9627  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 10 ), }. Only  9626  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 12 ), }. Only  9625  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 33 ), ( 16 , 12 ), }. Only  9624  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 11 , 121 ), }. Only  9623  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 12 , 0 ), }. Only  9620  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 0 ), ( 20 , 3 ), ( 20 , 7 ), }. Only  9619  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 3 ), ( 14 , 2 ), }. Only  9618  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 12 , 3 ), ( 14 , 3 ), }. Only  9616  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 12 , 3 ), ( 16 , 0 ), }. Only  9614  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 12 , 4 ), }. Only  9612  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 12 , 6 ), }. Only  9609  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 6 ), ( 15 , 0 ), }. Only  9608  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 6 ), ( 15 , 8 ), }. Only  9607  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 7 ), ( 13 , 2 ), }. Only  9606  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 8 ), ( 14 , 1 ), }. Only  9605  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 10 ), }. Only  9604  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 11 ), }. Only  9603  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 12 , 12 ), }. Only  9600  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 12 ), ( 14 , 10 ), }. Only  9599  left!
# Currently processing 7 genomes for { ( 0 , 0 ), ( 12 , 13 ), }. Only  9592  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 12 , 16 ), ( 14 , 14 ), }. Only  9591  left!
# Currently processing 4 genomes for { ( 0 , 0 ), ( 13 , 0 ), }. Only  9587  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 13 , 1 ), }. Only  9585  left!
# Currently processing 5 genomes for { ( 0 , 0 ), ( 13 , 2 ), }. Only  9580  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 13 , 5 ), }. Only  9578  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 6 ), ( 15 , 1 ), }. Only  9577  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 7 ), }. Only  9576  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 13 , 8 ), }. Only  9574  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 9 ), ( 14 , 4 ), }. Only  9573  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 13 , 10 ), }. Only  9571  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 10 ), ( 20 , 1 ), }. Only  9570  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 11 ), }. Only  9569  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 12 ), }. Only  9568  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 13 ), }. Only  9567  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 14 ), }. Only  9566  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 13 , 15 ), }. Only  9563  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 13 , 16 ), }. Only  9562  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 2 ), }. Only  9561  left!
# Currently processing 7 genomes for { ( 0 , 0 ), ( 14 , 2 ), ( 16 , 0 ), }. Only  9554  left!
# Currently processing 9 genomes for { ( 0 , 0 ), ( 14 , 5 ), }. Only  9545  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 14 , 6 ), }. Only  9543  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 7 ), ( 15 , 2 ), }. Only  9542  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 8 ), }. Only  9541  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 9 ), }. Only  9540  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 10 ), ( 16 , 14 ), }. Only  9539  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 11 ), }. Only  9538  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 12 ), }. Only  9537  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 14 , 13 ), }. Only  9536  left!
# Currently processing 5 genomes for { ( 0 , 0 ), ( 15 , 0 ), }. Only  9531  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 15 , 0 ), ( 16 , 0 ), }. Only  9529  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 15 , 3 ), }. Only  9527  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 15 , 4 ), }. Only  9526  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 15 , 7 ), }. Only  9524  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 15 , 9 ), ( 16 , 3 ), }. Only  9523  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 15 , 10 ), ( 16 , 4 ), }. Only  9522  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 15 , 11 ), }. Only  9520  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 15 , 13 ), }. Only  9518  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 15 , 14 ), }. Only  9517  left!
# Currently processing 6 genomes for { ( 0 , 0 ), ( 16 , 0 ), }. Only  9511  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 16 , 5 ), }. Only  9510  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 16 , 6 ), }. Only  9508  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 16 , 7 ), }. Only  9505  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 16 , 8 ), }. Only  9504  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 16 , 9 ), }. Only  9503  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 16 , 10 ), }. Only  9502  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 16 , 11 ), }. Only  9499  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 16 , 41 ), ( 18 , 6 ), }. Only  9498  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 17 , 0 ), }. Only  9495  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 17 , 1 ), }. Only  9494  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 17 , 2 ), }. Only  9492  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 17 , 3 ), ( 20 , 1 ), }. Only  9491  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 17 , 4 ), }. Only  9490  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 17 , 5 ), }. Only  9488  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 18 , 1 ), }. Only  9487  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 18 , 2 ), }. Only  9486  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 18 , 2 ), ( 23 , 0 ), }. Only  9485  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 18 , 3 ), }. Only  9484  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 19 , 0 ), ( 20 , 2 ), }. Only  9483  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 19 , 1 ), }. Only  9482  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 19 , 2 ), }. Only  9480  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 20 , 0 ), }. Only  9479  left!
# Currently processing 3 genomes for { ( 0 , 0 ), ( 20 , 3 ), }. Only  9476  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 20 , 4 ), }. Only  9475  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 20 , 6 ), }. Only  9473  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 21 , 0 ), }. Only  9472  left!
# Currently processing 2 genomes for { ( 0 , 0 ), ( 23 , 1 ), }. Only  9470  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 23 , 2 ), ( 23 , 3 ), }. Only  9469  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 24 , 0 ), ( 28 , 0 ), }. Only  9468  left!
# Currently processing 1 genomes for { ( 0 , 0 ), ( 28 , 0 ), ( 28 , 1 ), }. Only  9467  left!
# Currently processing 3 genomes for { ( 2 , 0 ), }. Only  9464  left!
# Currently processing 5 genomes for { ( 2 , 0 ), ( 3 , 0 ), }. Only  9459  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 3 , 0 ), ( 3 , 1 ), }. Only  9458  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 3 , 0 ), ( 8 , 0 ), }. Only  9456  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 3 , 0 ), ( 12 , 0 ), }. Only  9455  left!
# Currently processing 6 genomes for { ( 2 , 0 ), ( 3 , 1 ), }. Only  9449  left!
# Currently processing 4 genomes for { ( 2 , 0 ), ( 3 , 1 ), ( 4 , 0 ), }. Only  9445  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 3 , 1 ), ( 4 , 1 ), }. Only  9444  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 3 , 1 ), ( 5 , 1 ), }. Only  9443  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 3 , 1 ), ( 8 , 0 ), }. Only  9442  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 3 , 1 ), ( 12 , 0 ), }. Only  9441  left!
# Currently processing 8 genomes for { ( 2 , 0 ), ( 4 , 0 ), }. Only  9433  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 4 , 0 ), ( 5 , 1 ), }. Only  9432  left!
# Currently processing 4 genomes for { ( 2 , 0 ), ( 4 , 0 ), ( 8 , 0 ), }. Only  9428  left!
# Currently processing 10 genomes for { ( 2 , 0 ), ( 4 , 1 ), }. Only  9418  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 4 , 1 ), ( 5 , 1 ), }. Only  9417  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 4 , 1 ), ( 8 , 0 ), }. Only  9415  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 4 , 1 ), ( 12 , 0 ), }. Only  9414  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 4 , 2 ), }. Only  9412  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 4 , 3 ), }. Only  9411  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 4 , 4 ), }. Only  9409  left!
# Currently processing 6 genomes for { ( 2 , 0 ), ( 5 , 0 ), }. Only  9403  left!
# Currently processing 8 genomes for { ( 2 , 0 ), ( 5 , 1 ), }. Only  9395  left!
# Currently processing 3 genomes for { ( 2 , 0 ), ( 5 , 1 ), ( 8 , 0 ), }. Only  9392  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 5 , 1 ), ( 12 , 0 ), }. Only  9391  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 5 , 2 ), }. Only  9389  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 5 , 3 ), }. Only  9387  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 5 , 4 ), }. Only  9385  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 5 , 5 ), }. Only  9384  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 5 , 6 ), }. Only  9383  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 5 , 7 ), }. Only  9382  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 6 , 0 ), }. Only  9380  left!
# Currently processing 3 genomes for { ( 2 , 0 ), ( 6 , 1 ), }. Only  9377  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 6 , 2 ), }. Only  9375  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 6 , 3 ), }. Only  9373  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 6 , 5 ), }. Only  9372  left!
# Currently processing 4 genomes for { ( 2 , 0 ), ( 6 , 6 ), }. Only  9368  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 6 , 7 ), }. Only  9367  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 6 , 8 ), }. Only  9366  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 6 , 9 ), }. Only  9364  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 6 , 10 ), }. Only  9363  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 6 , 11 ), }. Only  9361  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 7 , 2 ), ( 8 , 0 ), }. Only  9359  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 7 , 3 ), }. Only  9357  left!
# Currently processing 4 genomes for { ( 2 , 0 ), ( 7 , 4 ), }. Only  9353  left!
# Currently processing 4 genomes for { ( 2 , 0 ), ( 7 , 5 ), }. Only  9349  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 7 , 7 ), }. Only  9347  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 7 , 8 ), }. Only  9345  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 7 , 9 ), }. Only  9343  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 7 , 10 ), }. Only  9342  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 7 , 11 ), }. Only  9341  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 7 , 12 ), }. Only  9340  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 7 , 13 ), }. Only  9339  left!
# Currently processing 17 genomes for { ( 2 , 0 ), ( 8 , 0 ), }. Only  9322  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 8 , 0 ), ( 12 , 0 ), }. Only  9320  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 8 , 2 ), }. Only  9318  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 8 , 3 ), }. Only  9316  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 8 , 4 ), }. Only  9314  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 8 , 5 ), }. Only  9313  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 8 , 6 ), }. Only  9312  left!
# Currently processing 3 genomes for { ( 2 , 0 ), ( 8 , 7 ), }. Only  9309  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 8 , 12 ), }. Only  9308  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 8 , 17 ), }. Only  9306  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 8 , 18 ), }. Only  9304  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 8 , 19 ), }. Only  9303  left!
# Currently processing 7 genomes for { ( 2 , 0 ), ( 9 , 0 ), }. Only  9296  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 9 , 1 ), }. Only  9294  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 9 , 4 ), }. Only  9293  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 9 , 5 ), }. Only  9291  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 9 , 6 ), }. Only  9290  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 9 , 15 ), }. Only  9289  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 10 , 0 ), }. Only  9288  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 10 , 0 ), ( 12 , 0 ), }. Only  9287  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 10 , 1 ), }. Only  9285  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 10 , 3 ), }. Only  9283  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 10 , 4 ), }. Only  9282  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 11 , 5 ), }. Only  9281  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 11 , 11 ), }. Only  9280  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 11 , 19 ), }. Only  9278  left!
# Currently processing 14 genomes for { ( 2 , 0 ), ( 12 , 0 ), }. Only  9264  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 12 , 2 ), }. Only  9262  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 12 , 26 ), }. Only  9260  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 12 , 35 ), }. Only  9259  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 12 , 71 ), }. Only  9257  left!
# Currently processing 4 genomes for { ( 2 , 0 ), ( 13 , 3 ), }. Only  9253  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 13 , 4 ), }. Only  9251  left!
# Currently processing 6 genomes for { ( 2 , 0 ), ( 16 , 0 ), }. Only  9245  left!
# Currently processing 6 genomes for { ( 2 , 0 ), ( 16 , 1 ), }. Only  9239  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 16 , 2 ), }. Only  9237  left!
# Currently processing 2 genomes for { ( 2 , 0 ), ( 16 , 12 ), }. Only  9235  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 16 , 43 ), }. Only  9234  left!
# Currently processing 3 genomes for { ( 2 , 0 ), ( 17 , 2 ), }. Only  9231  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 17 , 7 ), }. Only  9230  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 20 , 0 ), }. Only  9229  left!
# Currently processing 6 genomes for { ( 2 , 0 ), ( 20 , 1 ), }. Only  9223  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 20 , 10 ), }. Only  9222  left!
# Currently processing 1 genomes for { ( 2 , 0 ), ( 21 , 1 ), }. Only  9221  left!
# Currently processing 7 genomes for { ( 3 , 0 ), }. Only  9214  left!
# Currently processing 8 genomes for { ( 3 , 0 ), ( 3 , 1 ), }. Only  9206  left!
# Currently processing 1 genomes for { ( 3 , 0 ), ( 3 , 1 ), ( 4 , 1 ), }. Only  9205  left!
# Currently processing 1 genomes for { ( 3 , 0 ), ( 3 , 1 ), ( 5 , 1 ), }. Only  9204  left!
# Currently processing 2 genomes for { ( 3 , 0 ), ( 3 , 1 ), ( 8 , 0 ), }. Only  9202  left!
# Currently processing 1 genomes for { ( 3 , 0 ), ( 3 , 1 ), ( 12 , 0 ), }. Only  9201  left!
# Currently processing 8 genomes for { ( 3 , 0 ), ( 4 , 0 ), }. Only  9193  left!
# Currently processing 2 genomes for { ( 3 , 0 ), ( 4 , 0 ), ( 8 , 0 ), }. Only  9191  left!
# Currently processing 14 genomes for { ( 3 , 0 ), ( 4 , 1 ), }. Only  9177  left!
# Currently processing 1 genomes for { ( 3 , 0 ), ( 4 , 1 ), ( 5 , 1 ), }. Only  9176  left!
# Currently processing 2 genomes for { ( 3 , 0 ), ( 4 , 1 ), ( 8 , 0 ), }. Only  9174  left!
# Currently processing 1 genomes for { ( 3 , 0 ), ( 4 , 1 ), ( 12 , 0 ), }. Only  9173  left!
